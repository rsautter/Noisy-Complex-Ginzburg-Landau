# %%
from GPA import GPA
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from tqdm import tqdm
from scipy.signal import periodogram
from matplotlib.gridspec import GridSpec
import cv2

# %%
ga = GPA(0.03)
ga.version()
# Out:
# b'GPA - 3.5'

# %% [markdown]
# # Aspect Ratio

# %%
def convert2CV2(mat):
    m2 = (mat-np.min(mat))/(np.max(mat)-np.min(mat))
    m2 = m2*255
    m2 = m2.astype(np.uint8)
    return m2
def getBlobSizes(d):
    _,th = cv2.threshold(convert2CV2(d),0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    contours, hierarchy = cv2.findContours(th, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    blobSide = []
    for c in contours:
        (cx,cy),(w,h),theta = cv2.minAreaRect(c)
        blobSide.append(np.max([w,h])) 
    return blobSide

def getBlobStatistics(img):
    normedBlobSize = getBlobSizes(img)/np.max(img.shape)
    #print(normedBlobSize)
    return np.average(normedBlobSize), np.std(normedBlobSize)

# %% [markdown]
# ## Without Noise

# %%
data = np.load("data/withoutNoise/data.npy")
times = np.load("data/withoutNoise/times.npy")

# %%
avgwn,stds = [],[]
for d in data:
    avg,std = getBlobStatistics(np.real(d))
    avgwn.append(avg)

# %% [markdown]
# ## Additive Noise

# %%
data = np.load("data/additiveNoise/data.npy")
times = np.load("data/additiveNoise/times.npy")

# %%
avgan,stds = [],[]
for d in data:
    avg,std = getBlobStatistics(np.real(d))
    avgan.append(avg)

# %% [markdown]
# ## Multiplicative

# %%
data = np.load("data/multiplicativeNoise/data.npy")
times = np.load("data/multiplicativeNoise/times.npy")

# %%
avgmn,stds = [],[]
for d in data:
    avg,std = getBlobStatistics(np.real(d))
    avgmn.append(avg)

# %% [markdown]
# ## Plot

# %%
data = pd.DataFrame({"Without Noise":avgwn,"Additive Noise":avgan,"Multiplicative Noise":avgmn})
mean = data.rolling(window=100).mean().dropna()
std = data.rolling(window=100).std().dropna()
minimum = mean-std
maximum = mean+std
t = (mean.index.copy()/20)-4.95

# %%
t
# Out:
# Float64Index([                0.0, 0.04999999999999982, 0.09999999999999964,
#               0.14999999999999947, 0.20000000000000018,                0.25,
#                0.2999999999999998, 0.34999999999999964, 0.39999999999999947,
#                0.4500000000000002,
#               ...
#                144.60000000000002,              144.65,  144.70000000000002,
#                            144.75,               144.8,  144.85000000000002,
#                             144.9,  144.95000000000002,               145.0,
#                            145.05],
#              dtype='float64', length=2902)

# %%
wn  = np.array([0.01,0.18,0.25,0.34])
wnstd = np.array([0.0,0.08,0.09,0.1])

add  = np.array([0.01,0.14,0.21,0.68])
addstd = np.array([0.0,0.06,0.08,0.16])

mul  = np.array([0.01,0.16,0.23,0.32])
mulstd = np.array([0.0,0.09,0.12,0.12])
t = np.array([0,6,42,76])

# %%
from scipy.interpolate import CubicSpline

density = 1000
ct = np.linspace(0,76,density)

plt.figure(figsize=(10,5))
cs = CubicSpline(np.linspace(0,1,len(wn)),wn)
cmin, cmax = CubicSpline(np.linspace(0,1,len(wn)),wn-wnstd),CubicSpline(np.linspace(0,1,len(wn)),wn+wnstd)
plt.fill_between(ct,cmin(np.linspace(0,1,density)),cmax(np.linspace(0,1,density)),alpha=0.10,color='blue')
plt.plot(ct,cs(np.linspace(0,1,density)),color='blue',label="Without Noise")

cs = CubicSpline(np.linspace(0,1,len(wn)),add)
cmin, cmax = CubicSpline(np.linspace(0,1,len(add)),add-addstd),CubicSpline(np.linspace(0,1,len(add)),add+addstd)
plt.fill_between(ct,cmin(np.linspace(0,1,density)),cmax(np.linspace(0,1,density)),alpha=0.10,color='orange')
plt.plot(ct,cs(np.linspace(0,1,density)),color='orange',label="Additive Noise")

cs = CubicSpline(np.linspace(0,1,len(wn)),mul)
cmin, cmax = CubicSpline(np.linspace(0,1,len(mul)),mul-mulstd),CubicSpline(np.linspace(0,1,len(mul)),mul+mulstd)
plt.fill_between(ct,cmin(np.linspace(0,1,density)),cmax(np.linspace(0,1,density)),alpha=0.10,color='green')
plt.plot(ct,cs(np.linspace(0,1,density)),color='green',label="Multiplicative Noise")
plt.xlim(0,77)
plt.legend(fontsize=15)
plt.xlabel("Time",fontsize=15)
plt.ylabel("$\Gamma$(t)",fontsize=17)
plt.savefig("gamma.png",dpi=300, bbox_inches='tight')
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(20,5))


#plt.fill_between(t, minimum["Additive Noise"],maximum["Additive Noise"],color='orange',alpha=0.5)
plt.plot(t,mean["Additive Noise"],color='orange')

#plt.fill_between(t, minimum["Multiplicative Noise"],maximum["Multiplicative Noise"],color='green',alpha=0.5)
plt.plot(t,mean["Multiplicative Noise"],color='green')

#plt.fill_between(t, minimum["Without Noise"],maximum["Without Noise"],alpha=0.5)
plt.plot(t,mean["Without Noise"])
plt.xlim(0,100)
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# # Spatial Autocorrelation

# %%
def spatialCorrelation(mat,steps = None):
    dx = []
    dy = []
    step=[]
    
    if steps == None:
        s2 = np.arange(1,np.min(mat.shape)//2)
    else:
        s2 = steps
    m2 = mat.copy()
    m = (m2 - np.average(m2))/np.std(m2)
    for s in s2:
        dy.append(np.average(m[s:,:]*m[:-s,:]))
        dx.append(np.average(m[:,s:]*m[:,:-s]))
        step.append(s)
    dx,dy,step = np.array(dx),np.array(dy),np.array(step)
    return dx,dy,step

def temporalCorrelation(mats,steps = None):
    dt = []
    step=[]
    
    if steps == None:
        s2 = np.arange(1,mats.shape[0]//2)
    else:
        s2 = steps
    m2 = mats[:,mats.shape[1]//2,mats.shape[2]//2]
    m = (m2 - np.average(m2))/np.std(m2)
    for s in s2:
        dt.append(np.average(m[s:]*m[:-s]))
        step.append(s)
    dt,step = np.array(dt),np.array(step)
    return dt,step

# %% [markdown]
# ### Without Noise

# %%
data = np.load("data/withoutNoise/data.npy")
times = np.load("data/withoutNoise/times.npy")

# %%
dx0,dy,step = spatialCorrelation(np.real(data[0]))
plt.figure(figsize=(15,7))
plt.plot(step,dx0,label=f'$C_S(r,0)$')
dx,dy,step = spatialCorrelation(np.real(data[-1]))
plt.plot(step,dx,label=f'$C_S(r,t)$')
plt.legend(fontsize=20)
plt.xlabel("$r$",fontsize=20)
plt.ylabel("$C_s(r,t)$",fontsize=20)
plt.show()

# %%
dt,step = temporalCorrelation(np.real(data))
plt.figure(figsize=(15,7))
plt.plot(step*0.05,dt,label=f'$C(t)$')
plt.xlabel("t",fontsize=20)
plt.ylabel("$C(t)$",fontsize=20)
plt.show()

# %% [markdown]
# ### Additive Noise

# %%
data = np.load("data/additiveNoise/data.npy")
times = np.load("data/additiveNoise/times.npy")

# %%
dx0,dy,step = spatialCorrelation(np.real(data[0]))
plt.figure(figsize=(15,7))
plt.plot(step,dx0,label=f'$C_S(r,0)$')
dx,dy,step = spatialCorrelation(np.real(data[-1]))
plt.plot(step,dx,label=f'$C_S(r,t)$')
plt.legend(fontsize=20)
plt.xlabel("$r$",fontsize=20)
plt.ylabel("$C_s(r,t)$",fontsize=20)
plt.show()

# %%
dt,step = temporalCorrelation(np.real(data))
plt.figure(figsize=(15,7))
plt.plot(step*0.05,dt,label=f'$C(t)$')
plt.xlabel("t",fontsize=20)
plt.ylabel("$C(t)$",fontsize=20)
plt.show()

# %% [markdown]
# ### Multplicative Noise

# %%
data = np.load("data/multiplicativeNoise/data.npy")
times = np.load("data/multiplicativeNoise/times.npy")

# %%
dx0,dy,step = spatialCorrelation(np.real(data[0]))
plt.figure(figsize=(15,7))
plt.plot(step,dx0,label=f'$C_S(r,0)$')
dx,dy,step = spatialCorrelation(np.real(data[-1]))
plt.plot(step,dx,label=f'$C_S(r,t)$')
plt.legend(fontsize=20)
plt.xlabel("$r$",fontsize=20)
plt.ylabel("$C_s(r,t)$",fontsize=20)
plt.show()

# %%
dt,step = temporalCorrelation(np.real(data))
plt.figure(figsize=(15,7))
plt.plot(step*0.05,dt,label=f'$C(t)$')
plt.xlabel("t",fontsize=20)
plt.ylabel("$C(t)$",fontsize=20)
plt.show()
